# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexBeliyV/my-first-blog/blob/main/%D0%9C%D0%B8%D0%BD%D0%B8%20%D0%BF%D1%80%D0%BE%D0%B5%D0%BA%D1%82.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Business Task: Investigation of Declining Course Sales
#
# **Background**
# Our company specializes in selling online programming courses, available for purchase year-round. We have synthetic sales data covering the period from *January 2023 to May 2025*.
#
# In *May 2025*, a significant decline in sales was observed. Senior management has expressed concern and requested an urgent analysis to determine the causes of this drop and provide actionable recommendations.
#
# **Objectives**
#
# 1. Identify the primary reasons for the sales decline.
# 2. Evaluate potential actions, such as:
#
#    * Adjusting marketing strategies
#    * Relaunching or updating courses
#    * Introducing discounts or special offers
# 3. Provide data-driven recommendations for reversing the trend and increasing sales.
#
# **Scope of Work**
#
# * *Stage 1:* Initial Data Analysis (EDA)
# * *Stage 2:* In-depth Investigation
# * *Stage 3:* Conclusions & Recommendations
#
#   * Why did sales actually drop?
#   * Is any action required?
#   * Which measures should be prioritized?
#
# **Deliverables**
#
# 1. Jupyter Notebook containing:
#
#    * Data cleaning and preparation
#    * Exploratory Data Analysis with visualizations
#    * Key statistical findings
# 2. Google Presentation for the CEO including:
#
#    * Brief description of the task and data sources
#    * Key findings in clear, business-friendly language
#    * 3–5 actionable recommendations to increase sales
#    * Estimated potential impact of implementing recommendations
#
# **Expected Outcome**
# A clear understanding of the sales drop causes and a set of well-supported strategic recommendations to improve sales performance in the coming months.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('sample_data/course_sales.csv')
df.head()
# Out:
#       Sale Date           Course Name  Price$  Quantity  Total
# 0  Jan 01, 2023         Python Basics      50      18.0    900
# 1      01.01.23               DS Boot     200      10.0   2000
# 2  Jan 01, 2023       WEB DEVELOPMENT      80      16.0   1280
# 3    01/01/2023  Machine Learning ADV     250      11.0   2750
# 4    2023-01-01                   SQL      60      13.0    780

# %%
df = df.rename(columns={"Sale Date": "Sale_Date"})
df = df.rename(columns={"Course Name": "Course_Name"})

df
# Out:
#          Sale_Date           Course_Name  Price$  Quantity  Total
# 0     Jan 01, 2023         Python Basics      50      18.0    900
# 1         01.01.23               DS Boot     200      10.0   2000
# 2     Jan 01, 2023       WEB DEVELOPMENT      80      16.0   1280
# 3       01/01/2023  Machine Learning ADV     250      11.0   2750
# 4       2023-01-01                   SQL      60      13.0    780
# ...            ...                   ...     ...       ...    ...
# 4505    08/02/2025          ML (level 2)     250      15.0   3750
# 4506      27.10.24               web_dev      80      15.0   1200
# 4507  Jan 27, 2025  python for beginners      50      16.0    800
# 4508    20/03/2025          Data.Science     200      17.0   3400
# 4509  Dec 09, 2024           Web Dev 101      80      20.0   1600
#
# [4510 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['Sale_Date', 'Course_Name', 'Price$', 'Quantity', 'Total'], dtype='object')

# %%
import pandas as pd
from dateutil import parser



# Преобразуем колонку Sale_Date с помощью parser
df['Sale_Date'] = df['Sale_Date'].apply(lambda x: parser.parse(x, dayfirst=True))

# %%
df
# Out:
#       Sale_Date           Course_Name  Price$  Quantity  Total
# 0    2023-01-01         Python Basics      50      18.0    900
# 1    2023-01-01               DS Boot     200      10.0   2000
# 2    2023-01-01       WEB DEVELOPMENT      80      16.0   1280
# 3    2023-01-01  Machine Learning ADV     250      11.0   2750
# 4    2023-01-01                   SQL      60      13.0    780
# ...         ...                   ...     ...       ...    ...
# 4505 2025-02-08          ML (level 2)     250      15.0   3750
# 4506 2024-10-27               web_dev      80      15.0   1200
# 4507 2025-01-27  python for beginners      50      16.0    800
# 4508 2025-03-20          Data.Science     200      17.0   3400
# 4509 2024-12-09           Web Dev 101      80      20.0   1600
#
# [4510 rows x 5 columns]
